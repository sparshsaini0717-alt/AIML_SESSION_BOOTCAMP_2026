# %% [markdown]
# <a href="https://colab.research.google.com/github/sparshsaini0717-alt/AIML_SESSION_BOOTCAMP_2026/blob/main/GLA_ML_SESSION2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
subjects = ["Python", "Math", "AI", "Data"]
print(subjects)
print(subjects[0])
print(subjects[-1])
# Out:
# ['Python', 'Math', 'AI', 'Data']
# Python
# Data

# %%
age=int(input(" "))
if(age<13):
  print("Child")
elif(13<=age<=19):
  print("teenager")
else:
  print("Adult")
# Out:
#  45
# Adult

# %%
marks = 72

if marks>=40:
  print("Pass")
else:
  print("Fail")
# Out:
# Pass

# %%
dic=[
    {"class":"ca","college":"gla","name":"Sparsh","city":"mathura","grade":"a+"},
    {"class":"ca","college":"gla","name":"Kanak",'city': 'mathura', 'grade': 'b+'},
    {'class': 'ca', 'college': 'gla', 'name': 'rani', 'city': 'mathura', 'grade': 'a+'},
    {'class': 'ca', 'college': 'gla', 'name': 'ritika', 'city': 'mathura', 'grade': 'b'}
]
print(dic)
for student in dic:
    if student["grade"] == "a+":
        print(student["name"])
for student in dic:
  if student.get("grade") == "a+":
    print(student.get("name"))
# Out:
# [{'class': 'ca', 'college': 'gla', 'name': 'Sparsh', 'city': 'mathura', 'grade': 'a+'}, {'class': 'ca', 'college': 'gla', 'name': 'Kanak', 'city': 'mathura', 'grade': 'b+'}, {'class': 'ca', 'college': 'gla', 'name': 'rani', 'city': 'mathura', 'grade': 'a+'}, {'class': 'ca', 'college': 'gla', 'name': 'ritika', 'city': 'mathura', 'grade': 'b'}]
# Sparsh
# rani
# Sparsh
# rani

# %%
def calculate_average(marks):
  return sum(marks)/len(marks)
student_marks=[78,84,62]
average=calculate_average(student_marks)
print(average)
# Out:
# 74.66666666666667

# %%
marks=[78,84,62]
avg=sum(marks)/len(marks)
print(avg)
# Out:
# 74.66666666666667

# %%
def fun(mark):
  if(mark>=40):
    return "passed"
  else:
    return "failed"
mark=int(input("enter marks"))
print(fun(mark))
# Out:
# enter marks15
# failed

# %%
import numpy as np
marks = np.array([78,91,55,72,40,88])
print(marks.reshape(3,2))
# Out:
# [[78 91]
#  [55 72]
#  [40 88]]

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c26cd1c7-4815-4169-928e-05600ddd8823" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c26cd1c7-4815-4169-928e-05600ddd8823">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

# This dynamically grabs the filename and content of the uploaded file
filename = list(uploaded.keys())[0]

# If it's a true CSV file:
df = pd.read_csv(io.BytesIO(uploaded[filename]))

# Note: If it's actually an Excel file (and not just a misnamed CSV), use this instead:
# df = pd.read_excel(io.BytesIO(uploaded[filename]))

print(df)
# Out:
#     student_id    name  age     city  math  science  english  \
# 0          101   Aarav   16   Mumbai    78       84       69
# 1          102    Diya   16    Delhi    91       88       94
# 2          103   Kabir   17  Mathura    55       61       58
# 3          104   Meera   16    Noida    72       79       81
# 4          105   Rohan   17   Mumbai    40       52       47
# 5          106    Sara   16    Delhi    88       93       90
# 6          107  Ishaan   17  Mathura    64       70       66
# 7          108  Ananya   16    Noida    95       92       89
# 8          109  Vivaan   17   Mumbai    48       57       51
# 9          110    Tara   16    Delhi    83       76       85
# 10         111   Arjun   17  Mathura    67       63       72
# 11         112   Nisha   16    Noida    74       81       79
# 12         113     Dev   17   Mumbai    35       45       42
# 13         114   Priya   16    Delhi    89       86       91
# ...

# %%
df['average'] = df[['math', 'science', 'english']].mean(axis=1)
print(df['average'])
# Out:
# 0     77.000000
# 1     91.000000
# 2     58.000000
# 3     77.333333
# 4     46.333333
# 5     90.333333
# 6     66.666667
# 7     92.000000
# 8     52.000000
# 9     81.333333
# 10    67.333333
# 11    78.000000
# 12    40.666667
# 13    88.666667
# 14    57.333333
# 15    92.666667
# 16    65.000000
# 17    82.666667
# 18    46.000000
# 19    76.666667
# Name: average, dtype: float64

# %%
df['result'] = np.where(df['average'] >= 40, 'Pass', 'Fail')
print(df['result'])
# Out:
# 0     Pass
# 1     Pass
# 2     Pass
# 3     Pass
# 4     Pass
# 5     Pass
# 6     Pass
# 7     Pass
# 8     Pass
# 9     Pass
# 10    Pass
# 11    Pass
# 12    Pass
# 13    Pass
# 14    Pass
# 15    Pass
# 16    Pass
# 17    Pass
# 18    Pass
# 19    Pass
# Name: result, dtype: object

# %%
class_avg = df['average'].mean()

print(class_avg)
# Out:
# 71.35000000000001

# %%
highest_avg = df['average'].max()
lowest_avg = df['average'].min()
print(highest_avg)
print(lowest_avg)
# Out:
# 92.66666666666667
# 40.666666666666664

# %%
top_students = df[df['average'] == highest_avg]

print(top_students)
# Out:
#     student_id  name  age   city  math  science  english  attendance_percent  \
# 15         116  Riya   16  Noida    92       90       96                  98
#
#     study_hours_per_week  assignments_submitted  final_project_score  \
# 15                    13                     10                   96
#
#       average result
# 15  92.666667   Pass

# %%
low_attendance = df[df['attendance_percent'] < 75]
if not low_attendance.empty:
    print(low_attendance[['name', 'attendance_percent']])
else:
    print("No students found.")
# Out:
#       name  attendance_percent
# 4    Rohan                  68
# 8   Vivaan                  71
# 12     Dev                  62
# 18    Yash                  66

# %%
low_assignments = df[df['assignments_submitted'] < 6]
if not low_assignments.empty:
    print(low_assignments[['name', 'assignments_submitted']])
else:
    print("No students found.")
print()
# Out:
#      name  assignments_submitted
# 4   Rohan                      5
# 12    Dev                      4
# 18   Yash                      5

# %%
output_filename = "session4_student_report.csv"
df.to_csv(output_filename, index=False)
print(f"Final report successfully saved as: '{output_filename}'")
# Out:
# Final report successfully saved as: 'session4_student_report.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url="https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"

df=pd.read_csv(url)


print(df.head())
print(df.shape)
print(df.columns)
print(df.info())
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# (1704, 6)
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# ...

# %%
df = df.rename(columns={
    "lifeExp": "life_expectancy",
    "pop": "population",
    "gdpPercap": "gdp_per_capita"
})

print(df.head())
print(df.columns)
# Out:
#        country  year  population continent  life_expectancy  gdp_per_capita
# 0  Afghanistan  1952   8425333.0      Asia           28.801      779.445314
# 1  Afghanistan  1957   9240934.0      Asia           30.332      820.853030
# 2  Afghanistan  1962  10267083.0      Asia           31.997      853.100710
# 3  Afghanistan  1967  11537966.0      Asia           34.020      836.197138
# 4  Afghanistan  1972  13079460.0      Asia           36.088      739.981106
# Index(['country', 'year', 'population', 'continent', 'life_expectancy',
#        'gdp_per_capita'],
#       dtype='object')

# %%
print("Missing values in each column:")
print(df.isna().sum)

print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Missing values in each column:
# <bound method DataFrame.sum of       country   year  population  continent  life_expectancy  gdp_per_capita
# 0       False  False       False      False            False           False
# 1       False  False       False      False            False           False
# 2       False  False       False      False            False           False
# 3       False  False       False      False            False           False
# 4       False  False       False      False            False           False
# ...       ...    ...         ...        ...              ...             ...
# 1699    False  False       False      False            False           False
# 1700    False  False       False      False            False           False
# 1701    False  False       False      False            False           False
# 1702    False  False       False      False            False           False
# ...

# %%
df_clean = df.copy()

# Remove exact duplicate rows if any
if df_clean.duplicated().sum() > 0:
    df_clean = df_clean.drop_duplicates()

# Strip extra spaces from text columns
for col in ["country", "continent"]:
    df_clean[col] = df_clean[col].astype(str).str.strip()

# Ensure expected data types
df_clean["year"] = df_clean["year"].astype(int)
df_clean["population"] = df_clean["population"].astype(float)
df_clean["life_expectancy"] = df_clean["life_expectancy"].astype(float)
df_clean["gdp_per_capita"] = df_clean["gdp_per_capita"].astype(float)

print(df_clean.dtypes)
print(df_clean.head())
# Out:
# country             object
# year                 int64
# population         float64
# continent           object
# life_expectancy    float64
# gdp_per_capita     float64
# dtype: object
#        country  year  population continent  life_expectancy  gdp_per_capita
# 0  Afghanistan  1952   8425333.0      Asia           28.801      779.445314
# 1  Afghanistan  1957   9240934.0      Asia           30.332      820.853030
# 2  Afghanistan  1962  10267083.0      Asia           31.997      853.100710
# 3  Afghanistan  1967  11537966.0      Asia           34.020      836.197138
# 4  Afghanistan  1972  13079460.0      Asia           36.088      739.981106

# %%
dirty_demo = df_clean.head(12).copy()

# Deliberately introduce missing values for teaching practice
dirty_demo.loc[2, "life_expectancy"] = np.nan
dirty_demo.loc[5, "gdp_per_capita"] = np.nan

print(dirty_demo)
print(dirty_demo.isna().sum())

# Fill missing numerical values using median
clean_demo = dirty_demo.copy()
clean_demo["life_expectancy"] = clean_demo["life_expectancy"].fillna(clean_demo["life_expectancy"].median())
clean_demo["gdp_per_capita"] = clean_demo["gdp_per_capita"].fillna(clean_demo["gdp_per_capita"].median())

print(clean_demo.isna().sum())
print(clean_demo)
# Out:
#         country  year  population continent  life_expectancy  gdp_per_capita
# 0   Afghanistan  1952   8425333.0      Asia           28.801      779.445314
# 1   Afghanistan  1957   9240934.0      Asia           30.332      820.853030
# 2   Afghanistan  1962  10267083.0      Asia              NaN      853.100710
# 3   Afghanistan  1967  11537966.0      Asia           34.020      836.197138
# 4   Afghanistan  1972  13079460.0      Asia           36.088      739.981106
# 5   Afghanistan  1977  14880372.0      Asia           38.438             NaN
# 6   Afghanistan  1982  12881816.0      Asia           39.854      978.011439
# 7   Afghanistan  1987  13867957.0      Asia           40.822      852.395945
# 8   Afghanistan  1992  16317921.0      Asia           41.674      649.341395
# 9   Afghanistan  1997  22227415.0      Asia           41.763      635.341351
# 10  Afghanistan  2002  25268405.0      Asia           42.129      726.734055
# ...

# %%
year_min = df['year'].min()
year_max = df['year'].max()
print(f"Year range: {year_min} to {year_max}")
num_countries = df['country'].nunique()
print(f"Number of countries: {num_countries}")
num_continents = df['continent'].nunique()
print(f"Number of continents: {num_continents}")
# Out:
# Year range: 1952 to 2007
# Number of countries: 142
# Number of continents: 5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1. Load the data
url = "https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"
df = pd.read_csv(url)

# 2. Clean column names (removes any leading/trailing whitespace)
df.columns = df.columns.str.strip()

# 3. Verify columns (Optional, useful for debugging)
print("Columns in dataset:", df.columns.tolist())

# 4. Group by continent and calculate the mean of lifeExp
# Note: Ensure these strings match the cleaned column names
avg_life_exp_by_continent = df.groupby('continent')['lifeExp'].mean()

# 5. Plot the data as a bar chart
plt.figure(figsize=(10, 6))
avg_life_exp_by_continent.plot(kind='bar', color='skyblue', edgecolor='black')

# 6. Add labels and title
plt.title('Average Life Expectancy by Continent')
plt.xlabel('Continent')
plt.ylabel('Average Life Expectancy')
plt.xticks(rotation=45)

# 7. Display the plot
plt.tight_layout()
plt.show()
# Out:
# Columns in dataset: ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Ensure columns are cleaned
df.columns = df.columns.str.strip()

# 2. Filter the data for the three countries
countries = ['India', 'China', 'United States']
filtered_df = df[df['country'].isin(countries)]

# 3. Create the plot
plt.figure(figsize=(10, 6))

# Loop through each country to plot its trend
for country in countries:
    country_data = filtered_df[filtered_df['country'] == country]
    plt.plot(country_data['year'], country_data['lifeExp'], marker='o', label=country)

# 4. Add labels, title, and legend
plt.title('Life Expectancy Over Time (India, China, USA)')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Clean the column names to avoid KeyErrors
df.columns = df.columns.str.strip()

# 2. Filter the data for the year 2007
df_2007 = df[df['year'] == 2007]

# 3. Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df_2007['gdpPercap'], df_2007['lifeExp'], alpha=0.6, color='purple')

# 4. Add labels and title
plt.title('GDP per Capita vs Life Expectancy in 2007')
plt.xlabel('GDP per Capita')
plt.ylabel('Life Expectancy')
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()
